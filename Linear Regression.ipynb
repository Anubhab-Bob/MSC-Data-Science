# %% [markdown]
# # Linear Regression Model using sklearn
#
# LinearRegression fits a linear model with coefficients w = (w1, …, wp) to minimize the residual sum of squares between the observed targets in the dataset, and the targets predicted by the linear approximation.

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn import datasets, linear_model

# %%
# Load dataset
dataset = datasets.load_diabetes(as_frame=True)
print(dataset.data)
print(dataset.target)
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017282 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081414  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 0   -0.002592  0.019908 -0.017646
# ...

# %%
# Show relation between different attributes
fig, axs = plt.subplots(2, 3)
axs[0, 0].scatter(dataset["age"],dataset["sex"])
axs[0, 0].set_xlabel("age")
axs[0, 0].set_ylabel("sex")
axs[0, 1].scatter(dataset["age"],dataset["bmi"])
axs[0, 1].set_xlabel("age")
axs[0, 1].set_ylabel("bmi")
axs[0, 2].scatter(dataset["age"],dataset["bp"])
axs[0, 2].set_xlabel("age")
axs[0, 2].set_ylabel("bp")
axs[1, 0].scatter(dataset["sex"],dataset["bmi"])
axs[1, 0].set_xlabel("sex")
axs[1, 0].set_ylabel("bmi")
axs[1, 1].scatter(dataset["sex"],dataset["bp"])
axs[1, 1].set_xlabel("sex")
axs[1, 1].set_ylabel("bp")
axs[1, 2].scatter(dataset["bmi"],dataset["bp"])
axs[1, 2].set_xlabel("bmi")
axs[1, 2].set_ylabel("bp")
fig.tight_layout()
plt.show()

# %%
# Load the diabetes dataset
diabetes_X, diabetes_y = datasets.load_diabetes(return_X_y=True, as_frame=True)
# Use only bmi feature
diabetes_X = np.array(diabetes_X["bmi"]).reshape(-1,1)
print(diabetes_X)
print(diabetes_y)
# Out:
# [[ 0.06169621]
#  [-0.05147406]
#  [ 0.04445121]
#  [-0.01159501]
#  [-0.03638469]
#  [-0.04069594]
#  [-0.04716281]
#  [-0.00189471]
#  [ 0.06169621]
#  [ 0.03906215]
#  [-0.08380842]
#  [ 0.01750591]
#  [-0.02884001]
#  [-0.00189471]
#  [-0.02560657]
#  [-0.01806189]
#  [ 0.04229559]
#  [ 0.01211685]
#  [-0.0105172 ]
#  [-0.01806189]
#  [-0.05686312]
#  [-0.02237314]
#  [-0.00405033]
#  [ 0.06061839]
#  [ 0.03582872]
#  [-0.01267283]
#  [-0.07734155]
#  [ 0.05954058]
#  [-0.02129532]
#  [-0.00620595]
#  [ 0.04445121]
#  [-0.06548562]
#  [ 0.12528712]
#  [-0.05039625]
#  [-0.06332999]
#  [-0.03099563]
#  [ 0.02289497]
#  [ 0.01103904]
#  [ 0.07139652]
#  [ 0.01427248]
#  [-0.00836158]
#  [-0.06764124]
#  [-0.0105172 ]
#  [-0.02345095]
#  [ 0.06816308]
#  [-0.03530688]
#  [-0.01159501]
#  [-0.0730303 ]
#  [-0.04177375]
#  [ 0.01427248]
#  [-0.00728377]
#  [ 0.0164281 ]
#  [-0.00943939]
#  [-0.01590626]
#  [ 0.0250506 ]
#  [-0.04931844]
#  [ 0.04121778]
#  [-0.06332999]
# ...

# %%
# Split the data into training/testing sets
diabetes_X_train = diabetes_X[:-20]
diabetes_X_test = diabetes_X[-20:]

# Split the targets into training/testing sets
diabetes_y_train = diabetes_y[:-20]
diabetes_y_test = diabetes_y[-20:]


# Model can also be prepared by not creating separate training/testing sets

# %%
# Create and fit model
model = linear_model.LinearRegression(n_jobs=-1)
model.fit(diabetes_X_train,diabetes_y_train)
# Make predictions using the testing set
diabetes_y_pred = model.predict(diabetes_X_test)
r_sq = model.score(diabetes_X_test,diabetes_y_test)
# Show results
print('Coefficients : %.3f'
      % model.coef_)
# The mean squared error
print('Intercept : %.2f'
      % model.intercept_)
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination : %.3f'
      % r_sq)
# Out:
# Coefficients : 938.238
# Intercept : 152.92
# Coefficient of determination : 0.473

# %%
# Plot results
plt.scatter(diabetes_X_test, diabetes_y_test,  color='red')
plt.plot(diabetes_X_test, diabetes_y_pred, color='black')
plt.show()
